# %% [markdown]
# <a href="https://colab.research.google.com/github/nrwpradana/Predict-Serie-A-Match/blob/main/Predict_Serie_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
matches = pd.read_csv("/content/matches_seriea.csv", index_col=0)

# %%
matches
# Out:
#           date   time     comp         round  day venue result   gf   ga  \
# 0   2022-08-15  18:30  Serie A   Matchweek 1  Mon  Away      W  5.0  2.0
# 1   2022-08-21  18:30  Serie A   Matchweek 2  Sun  Home      W  4.0  0.0
# 2   2022-08-28  20:45  Serie A   Matchweek 3  Sun  Away      D  0.0  0.0
# 3   2022-08-31  20:45  Serie A   Matchweek 4  Wed  Home      D  1.0  1.0
# 4   2022-09-03  20:45  Serie A   Matchweek 5  Sat  Away      W  2.0  1.0
# ..         ...    ...      ...           ...  ...   ...    ...  ...  ...
# 36  2021-05-03  20:45  Serie A  Matchweek 34  Mon  Away      L  0.0  1.0
# 37  2021-05-09  15:00  Serie A  Matchweek 35  Sun  Home      L  2.0  5.0
# 38  2021-05-12  20:45  Serie A  Matchweek 36  Wed  Away      L  0.0  1.0
# 39  2021-05-16  18:00  Serie A  Matchweek 37  Sun  Home      L  1.0  3.0
# 40  2021-05-22  20:45  Serie A  Matchweek 38  Sat  Away      L  0.0  3.0
#
#          opponent  ...  match report  notes    sh  sot  dist   fk pk pkatt  \
# ...

# %%
matches.shape
# Out:
# (1772, 27)

# %%
matches["team"].value_counts()
# Out:
# Napoli            89
# Bologna           89
# Atalanta          89
# Spezia            89
# Udinese           89
# Milan             89
# Sassuolo          89
# Torino            89
# Hellas Verona     88
# Sampdoria         88
# Fiorentina        88
# Juventus          88
# Internazionale    88
# Lazio             88
# Roma              88
# Cagliari          76
# Genoa             76
# Salernitana       51
# Empoli            51
# Venezia           38
# Benevento         38
# Crotone           38
# Parma             38
# Lecce             13
# Cremonese         13
# Monza             12
# Name: team, dtype: int64

# %%
matches["round"].value_counts()
# Out:
# Matchweek 1     60
# Matchweek 2     60
# Matchweek 3     60
# Matchweek 4     60
# Matchweek 5     60
# Matchweek 6     60
# Matchweek 7     60
# Matchweek 8     60
# Matchweek 9     60
# Matchweek 10    60
# Matchweek 11    60
# Matchweek 12    60
# Matchweek 13    52
# Matchweek 37    40
# Matchweek 36    40
# Matchweek 35    40
# Matchweek 34    40
# Matchweek 33    40
# Matchweek 32    40
# Matchweek 26    40
# Matchweek 31    40
# Matchweek 30    40
# Matchweek 29    40
# Matchweek 28    40
# Matchweek 27    40
# Matchweek 20    40
# Matchweek 25    40
# Matchweek 24    40
# Matchweek 23    40
# Matchweek 22    40
# Matchweek 21    40
# Matchweek 19    40
# Matchweek 18    40
# Matchweek 17    40
# Matchweek 16    40
# Matchweek 15    40
# Matchweek 14    40
# Matchweek 38    40
# Name: round, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes            object
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk                int64
# pkatt             int64
# season            int64
# team             object
# dtype: object

# %%
del matches["comp"]

# %%
del matches["notes"]

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches
# Out:
#          date   time         round  day venue result   gf   ga       opponent  \
# 0  2022-08-15  18:30   Matchweek 1  Mon  Away      W  5.0  2.0  Hellas Verona
# 1  2022-08-21  18:30   Matchweek 2  Sun  Home      W  4.0  0.0          Monza
# 2  2022-08-28  20:45   Matchweek 3  Sun  Away      D  0.0  0.0     Fiorentina
# 3  2022-08-31  20:45   Matchweek 4  Wed  Home      D  1.0  1.0          Lecce
# 4  2022-09-03  20:45   Matchweek 5  Sat  Away      W  2.0  1.0          Lazio
# ..        ...    ...           ...  ...   ...    ...  ...  ...            ...
# 36 2021-05-03  20:45  Matchweek 34  Mon  Away      L  0.0  1.0         Torino
# 37 2021-05-09  15:00  Matchweek 35  Sun  Home      L  2.0  5.0       Atalanta
# 38 2021-05-12  20:45  Matchweek 36  Wed  Away      L  0.0  1.0          Lazio
# 39 2021-05-16  18:00  Matchweek 37  Sun  Home      L  1.0  3.0       Sassuolo
# 40 2021-05-22  20:45  Matchweek 38  Sat  Away      L  0.0  3.0      Sampdoria
#
# ...

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches
# Out:
#          date   time         round  day venue result   gf   ga       opponent  \
# 0  2022-08-15  18:30   Matchweek 1  Mon  Away      W  5.0  2.0  Hellas Verona
# 1  2022-08-21  18:30   Matchweek 2  Sun  Home      W  4.0  0.0          Monza
# 2  2022-08-28  20:45   Matchweek 3  Sun  Away      D  0.0  0.0     Fiorentina
# 3  2022-08-31  20:45   Matchweek 4  Wed  Home      D  1.0  1.0          Lecce
# 4  2022-09-03  20:45   Matchweek 5  Sat  Away      W  2.0  1.0          Lazio
# ..        ...    ...           ...  ...   ...    ...  ...  ...            ...
# 36 2021-05-03  20:45  Matchweek 34  Mon  Away      L  0.0  1.0         Torino
# 37 2021-05-09  15:00  Matchweek 35  Sun  Home      L  2.0  5.0       Atalanta
# 38 2021-05-12  20:45  Matchweek 36  Wed  Away      L  0.0  1.0          Lazio
# 39 2021-05-16  18:00  Matchweek 37  Sun  Home      L  1.0  3.0       Sassuolo
# 40 2021-05-22  20:45  Matchweek 38  Sat  Away      L  0.0  3.0      Sampdoria
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2022-01-01']

# %%
test = matches[matches["date"] > '2022-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
error = accuracy_score(test["target"], preds)

# %%
error
# Out:
# 0.582018927444795

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted    0    1
# actual
# 0          287  116
# 1          149   82

# %%
from sklearn.metrics import precision_score
precision_score(test["target"], preds)
# Out:
# 0.41414141414141414

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Internazionale").sort_values("date")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          date   time         round  day venue result   gf   ga     opponent  \
# 3  2020-10-17  18:00   Matchweek 4  Sat  Home      L  1.0  2.0        Milan
# 5  2020-10-24  18:00   Matchweek 5  Sat  Away      W  2.0  0.0        Genoa
# 7  2020-10-31  18:00   Matchweek 6  Sat  Home      D  2.0  2.0        Parma
# 9  2020-11-08  15:00   Matchweek 7  Sun  Away      D  1.0  1.0     Atalanta
# 10 2020-11-22  15:00   Matchweek 8  Sun  Home      W  4.0  2.0       Torino
# ..        ...    ...           ...  ...   ...    ...  ...  ...          ...
# 9  2022-10-01  18:00   Matchweek 8  Sat  Home      L  1.0  2.0         Roma
# 11 2022-10-08  15:00   Matchweek 9  Sat  Away      W  2.0  1.0     Sassuolo
# 13 2022-10-16  12:30  Matchweek 10  Sun  Home      W  2.0  0.0  Salernitana
# 14 2022-10-22  20:45  Matchweek 11  Sat  Away      W  4.0  3.0   Fiorentina
# 16 2022-10-29  20:45  Matchweek 12  Sat  Home      W  3.0  0.0    Sampdoria
#
# ...

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                   date   time         round  day venue result   gf   ga  \
# team
# Atalanta 3  2020-10-17  15:00   Matchweek 4  Sat  Away      L  1.0  4.0
#          5  2020-10-24  15:00   Matchweek 5  Sat  Home      L  1.0  3.0
#          7  2020-10-31  15:00   Matchweek 6  Sat  Away      W  2.0  1.0
#          9  2020-11-08  15:00   Matchweek 7  Sun  Home      D  1.0  1.0
#          10 2020-11-21  18:00   Matchweek 8  Sat  Away      D  0.0  0.0
# ...                ...    ...           ...  ...   ...    ...  ...  ...
# Venezia  36 2022-05-01  12:30  Matchweek 35  Sun  Away      L  1.0  2.0
#          37 2022-05-05  18:00  Matchweek 20  Thu  Away      L  1.0  2.0
#          38 2022-05-08  15:00  Matchweek 36  Sun  Home      W  4.0  3.0
#          39 2022-05-14  20:45  Matchweek 37  Sat  Away      D  1.0  1.0
#          40 2022-05-22  21:00  Matchweek 38  Sun  Home      D  0.0  0.0
#
#                 opponent   xg  ...  hour  day_code  gf_rolling ga_rolling  \
# ...

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time         round  day venue result   gf   ga     opponent  \
# 3  2020-10-17  15:00   Matchweek 4  Sat  Away      L  1.0  4.0       Napoli
# 5  2020-10-24  15:00   Matchweek 5  Sat  Home      L  1.0  3.0    Sampdoria
# 7  2020-10-31  15:00   Matchweek 6  Sat  Away      W  2.0  1.0      Crotone
# 9  2020-11-08  15:00   Matchweek 7  Sun  Home      D  1.0  1.0        Inter
# 10 2020-11-21  18:00   Matchweek 8  Sat  Away      D  0.0  0.0       Spezia
# ..        ...    ...           ...  ...   ...    ...  ...  ...          ...
# 36 2022-05-01  12:30  Matchweek 35  Sun  Away      L  1.0  2.0     Juventus
# 37 2022-05-05  18:00  Matchweek 20  Thu  Away      L  1.0  2.0  Salernitana
# 38 2022-05-08  15:00  Matchweek 36  Sun  Home      W  4.0  3.0      Bologna
# 39 2022-05-14  20:45  Matchweek 37  Sat  Away      D  1.0  1.0         Roma
# 40 2022-05-22  21:00  Matchweek 38  Sun  Home      D  0.0  0.0     Cagliari
#
# ...

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2022-01-01']
    test = data[data["date"] > '2022-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error

# %%
combined, error = make_predictions(matches_rolling, predictors + new_cols)

# %%
error
# Out:
# 0.4774193548387097

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined.head(10)
# Out:
#     actual  predicted       date      team    opponent result
# 54       1          0 2022-01-09  Atalanta     Udinese      W
# 55       0          0 2022-01-16  Atalanta       Inter      D
# 56       0          0 2022-01-22  Atalanta       Lazio      D
# 57       0          1 2022-02-06  Atalanta    Cagliari      L
# 58       0          0 2022-02-13  Atalanta    Juventus      D
# 59       0          0 2022-02-20  Atalanta  Fiorentina      L
# 60       1          0 2022-02-28  Atalanta   Sampdoria      W
# 61       0          0 2022-03-05  Atalanta        Roma      L
# 62       0          0 2022-03-13  Atalanta       Genoa      D
# 63       1          0 2022-03-20  Atalanta     Bologna      W

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Internazionale": "Inter"} 
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#      actual_x  predicted_x       date    team_x   opponent_x result_x  \
# 0           1            0 2022-01-09  Atalanta      Udinese        W
# 1           0            0 2022-01-16  Atalanta        Inter        D
# 2           0            0 2022-01-22  Atalanta        Lazio        D
# 3           0            1 2022-02-06  Atalanta     Cagliari        L
# 4           0            0 2022-02-13  Atalanta     Juventus        D
# ..        ...          ...        ...       ...          ...      ...
# 611         0            0 2022-05-01   Venezia     Juventus        L
# 612         0            0 2022-05-05   Venezia  Salernitana        L
# 613         1            0 2022-05-08   Venezia      Bologna        W
# 614         0            0 2022-05-14   Venezia         Roma        D
# 615         0            0 2022-05-22   Venezia     Cagliari        D
#
#     new_team_x  actual_y  predicted_y          team_y opponent_y result_y  \
# ...

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# 1    68
# 0    64
# Name: actual_x, dtype: int64
